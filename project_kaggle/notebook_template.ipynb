# %% [markdown]
# # Kaggle Project Notebook Template
#
# Objective: Minimal template to load, explore, clean, and visualize a supply-chain dataset.
#
# Steps:
# 1. Describe dataset and objective
# 2. Load data
# 3. Quick QA / cleaning
# 4. Visualize one insight
# 5. Save outputs

# %%
# Libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Example: load data
# df = pd.read_csv('data/raw.csv')
# df.head()
